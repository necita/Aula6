# %%
import matplotlib.pyplot as plt
import numpy as np

def funcao(y):
    
    return 3-2*y 
def funcao1(y):
    
    return (-2 + y)/3

n = np.linspace(0,2, num=1000)
plt.plot(n, funcao(n))
plt.plot(n, funcao1(n), color="red")
plt.show()

# %%
a=np.array([[2,1],[1,-3]])
b=np.array([3,-2])
x=np.linalg.solve(a,b)
print(x)
# Out:
# [ 1.  1.]

# %%
def funcao(y):
    
    return 3-2*y 
def funcao1(y):
    
    return (6 -4*y)/2

n = np.linspace(0,2, num=1000)
plt.plot(n, funcao(n))
plt.plot(n, funcao1(n), color="red")
plt.show()

# %%
def funcao(y):
    
    return 3-2*y 
def funcao1(y):
    
    return (2 -4*y)/2

n = np.linspace(0,2, num=1000)
plt.plot(n, funcao(n))
plt.plot(n, funcao1(n), color="red")
plt.show()

# %%
A  = np.matrix([[2, 1], [1, -3]])
print(a)


v  = np.array(   [1, 1]  )
print('v', v)
u = np.matmul(A.data, v)
print('u ', u)
w = np.array(   [2, -1]  )
print('w', w)
t = np.matmul(A.data, w)
print('t ', t)
# Out:
# [[ 2  1]
#  [ 1 -3]]
# v [1 1]
# u  [ 3 -2]
# w [ 2 -1]
# t  [3 5]

# %%
plt.plot( [0,w[0]],[0, w[1]] , color="green")
plt.plot([0,v[0]],[0, v[1]] , color="pink")
plt.show()

# %%
plt.plot( [0,t[0]],[0, t[1]] , color="blue")
plt.plot([0,u[0]],[0, u[1]] , color="red")
plt.show()

# %%
a1 = np.array(   [2, 1]  )
print('a1', a1)

a2 = np.array(   [1, -3]  )
print('a2', a2)

u= 2 * a1 + a2
print (u)
# Out:
# a1 [2 1]
# a2 [ 1 -3]
# [ 5 -1]

# %%
plt.plot( [0,a1[0]],[0, a1[1]] , color="blue")
plt.plot([0,a2[0]],[0, a2[1]] , color="red")
plt.plot([0,2*a1[0]],[0, 2*a1[1]] , color="pink")
plt.plot([0,u[0]],[0, u[1]] , color="green")
plt.show()
